# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("\nMy name:Daniyal Atif\nMy Father name:Atif Jahangir\nMy D.O.B:18-3-2013")
# Out:
# My name:Daniyal Atif
# My Father name:Atif Jahangir
# My D.O.B:18-3-2013

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Daniyal Atif"
age = 13
school = "APSACS SR"
hobbies = "Coding,Gaming"

print("My name is",name)
print("I am",age,"years old")
print("I study at",school)
print("My hobbies are",hobbies)
# Out:
# My name is Daniyal Atif
# I am 13 years old
# I study at APSACS SR
# My hobbies are Coding,Gaming

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Arithmetic Operators
a = 10
b = 3
print("a + b =", a + b)      # Addition
print("a - b =", a - b)      # Subtraction
print("a * b =", a * b)      # Multiplication
print("a / b =", a / b)      # Division
print("a % b =", a % b)      # Modulus
print("a ** b =", a ** b)    # Power
print("a // b =", a // b)    # Floor Division

# Assignment Operators
c = 5
c += 2
print("c after +=2:", c)
c -= 1
print("c after -=1:", c)
c *= 3
print("c after *=3:", c)
c /= 2
print("c after /=2:", c)
c %= 4
print("c after %=4:", c)

# Comparison Operators
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
# Out:
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a % b = 1
# a ** b = 1000
# a // b = 3
# c after +=2: 7
# c after -=1: 6
# c after *=3: 18
# c after /=2: 9.0
# c after %=4: 1.0
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
marks_english = 93
marks_islamiat = 89
marks_maths = 97
total_marks = 300

obtained_marks = marks_english + marks_islamiat + marks_maths
percentage = (obtained_marks / total_marks)* 100

print("English Marks:",marks_english)
print("Islamiat Marks:",marks_islamiat)
print("Maths Marks:",marks_maths)
print("Total Marks:",total_marks)
print("Obtained Marks:",obtained_marks)
print("Percentage:",percentage)
# Out:
# English Marks: 93
# Islamiat Marks: 89
# Maths Marks: 97
# Total Marks: 300
# Obtained Marks: 279
# Percentage: 93.0
